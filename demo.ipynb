# %% [markdown]
# # Demo

# %%
from BiteAWX import AWX

# %%
path_awx = './test_data/ANI_IR2_R01_20230217_0800_FY2G.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	ESLF170A.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	248
# record_length:	1200
# head_records:	3
# data_records:	1200
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY2G
# year:	2023
# month:	2
# day:	17
# hour:	0
# minute:	0
# channel:	3
# projection:	1
# width:	1200
# height:	1200
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	62.06
# lat_s:	6.59
# lon_w:	77.32
# lon_e:	148.7
# lat_c:	35.0
# lon_c:	100.0
# prj_std1:	30.0
# prj_std2:	60.0
# reso_h:	5.0
# reso_v:	5.0
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * Head3 *
# sat2004:	/DPCFY2G/L1/ANI/FY2G_ANI_IR2_R01_20230217_0000.AWX
# format_version:	SAT2004
# manufacturer:	NSMC
# satellite:	FY2G
# instrument:
# program_version:	V1.0
# reserved:
# copy_right:	NSMC
# pad_length:
# <xarray.Dataset>
# Dimensions:  (y: 1200, x: 1200)
# Coordinates:
#   * y        (y) float64 2.998e+06 2.992e+06 2.988e+06 ... -2.992e+06 -2.998e+06
#   * x        (x) float64 -2.998e+06 -2.992e+06 ... 2.992e+06 2.998e+06
#     time     datetime64[ns] 2023-02-17
#     crs      float64 nan
# Data variables:
#     ANI      (y, x) uint8 202 202 203 202 202 202 ... 125 125 124 125 125 125

# %%
path_awx = './test_data/ANI_VIS_R02_20230217_1000_FY2G.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	EVNF172A.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	76
# record_length:	2228
# head_records:	2
# data_records:	1100
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY2G
# year:	2023
# month:	2
# day:	17
# hour:	2
# minute:	0
# channel:	4
# projection:	2
# width:	2228
# height:	1100
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	41.05
# lat_s:	-4.25
# lon_w:	59.98
# lon_e:	160.0
# lat_c:	20.0
# lon_c:	110.0
# prj_std1:	30.0
# prj_std2:	60.0
# reso_h:	5.0
# reso_v:	5.0
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * Head3 *
# sat2004:	/DPCFY2G/L1/ANI/FY2G_ANI_VIS_R02_20230217_0200.AWX
# format_version:	SAT2004
# manufacturer:	NSMC
# satellite:	FY2G
# instrument:
# program_version:	V1.0
# reserved:
# copy_right:	NSMC
# pad_length:
# <xarray.Dataset>
# Dimensions:  (y: 1100, x: 2228)
# Coordinates:
#   * y        (y) float64 4.705e+06 4.7e+06 4.695e+06 ... -7.85e+05 -7.9e+05
#   * x        (x) float64 -5.568e+06 -5.562e+06 ... 5.562e+06 5.568e+06
#     time     datetime64[ns] 2023-02-17T02:00:00
#     crs      float64 nan
# Data variables:
#     ANI      (y, x) uint8 0 0 0 4 0 0 0 0 0 0 ... 80 72 68 60 56 64 60 56 56 56

# %%
path_awx = './test_data/C002_20190302081500_FY4A.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	EIEN015C.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	4849
# record_length:	7001
# head_records:	1
# data_records:	4001
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY4-006
# year:	2019
# month:	3
# day:	2
# hour:	0
# minute:	15
# channel:	4
# projection:	4
# width:	7001
# height:	4001
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	55.0
# lat_s:	15.0
# lon_w:	70.0
# lon_e:	140.0
# lat_c:	35.0
# lon_c:	105.0
# prj_std1:	0.0
# prj_std2:	0.0
# reso_h:	0.05
# reso_v:	0.05
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * No Head3 found *
# <xarray.Dataset>
# Dimensions:  (lat: 4001, lon: 7001)
# Coordinates:
#   * lat      (lat) float64 55.0 54.99 54.98 54.97 ... 15.03 15.02 15.01 15.0
#   * lon      (lon) float64 70.0 70.01 70.02 70.03 ... 140.0 140.0 140.0 140.0
#     time     datetime64[ns] 2019-03-02T00:15:00
#     crs      float64 nan
# Data variables:
#     Unknown  (lat, lon) uint8 3 3 3 3 3 3 3 3 3 3 ... 55 67 63 55 55 43 39 27 31

# %%
path_awx = './test_data/C009_20190301161500_FY4A.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	EIEN015C.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	1350
# record_length:	1751
# head_records:	2
# data_records:	1001
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY4-062
# year:	2019
# month:	3
# day:	1
# hour:	8
# minute:	15
# channel:	2
# projection:	4
# width:	1751
# height:	1001
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	55.0
# lat_s:	15.0
# lon_w:	70.0
# lon_e:	140.0
# lat_c:	35.0
# lon_c:	105.0
# prj_std1:	0.0
# prj_std2:	0.0
# reso_h:	0.05
# reso_v:	0.05
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * No Head3 found *
# <xarray.Dataset>
# Dimensions:  (lat: 1001, lon: 1751)
# Coordinates:
#   * lat      (lat) float64 55.0 54.96 54.92 54.88 ... 15.12 15.08 15.04 15.0
#   * lon      (lon) float64 70.0 70.04 70.08 70.12 ... 139.9 139.9 140.0 140.0
#     time     datetime64[ns] 2019-03-01T08:15:00
#     crs      float64 nan
# Data variables:
#     Unknown  (lat, lon) uint8 226 226 226 226 226 226 ... 192 192 192 192 192

# %%
path_awx = './test_data/C012_20190301160000_FY4A.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	EIEN015C.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	349
# record_length:	2501
# head_records:	1
# data_records:	3501
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY4-108
# year:	2019
# month:	3
# day:	1
# hour:	8
# minute:	0
# channel:	1
# projection:	4
# width:	2501
# height:	3501
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	70.0
# lat_s:	-70.0
# lon_w:	70.0
# lon_e:	170.0
# lat_c:	0.0
# lon_c:	120.0
# prj_std1:	0.0
# prj_std2:	0.0
# reso_h:	0.05
# reso_v:	0.05
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * No Head3 found *
# <xarray.Dataset>
# Dimensions:  (lat: 3501, lon: 2501)
# Coordinates:
#   * lat      (lat) float64 70.0 69.96 69.92 69.88 ... -69.88 -69.92 -69.96 -70.0
#   * lon      (lon) float64 70.0 70.04 70.08 70.12 ... 169.9 169.9 170.0 170.0
#     time     datetime64[ns] 2019-03-01T08:00:00
#     crs      float64 nan
# Data variables:
#     Unknown  (lat, lon) uint8 194 194 194 194 194 194 ... 180 180 180 180 180

# %%
path_awx = './test_data/C012_20190302101500_FY4A.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	EIEN015C.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	1350
# record_length:	1751
# head_records:	2
# data_records:	1001
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY4-108
# year:	2019
# month:	3
# day:	2
# hour:	2
# minute:	15
# channel:	1
# projection:	4
# width:	1751
# height:	1001
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	55.0
# lat_s:	15.0
# lon_w:	70.0
# lon_e:	140.0
# lat_c:	35.0
# lon_c:	105.0
# prj_std1:	0.0
# prj_std2:	0.0
# reso_h:	0.05
# reso_v:	0.05
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * No Head3 found *
# <xarray.Dataset>
# Dimensions:  (lat: 1001, lon: 1751)
# Coordinates:
#   * lat      (lat) float64 55.0 54.96 54.92 54.88 ... 15.12 15.08 15.04 15.0
#   * lon      (lon) float64 70.0 70.04 70.08 70.12 ... 139.9 139.9 140.0 140.0
#     time     datetime64[ns] 2019-03-02T02:15:00
#     crs      float64 nan
# Data variables:
#     Unknown  (lat, lon) uint8 184 184 184 184 183 183 ... 103 103 103 103 104

# %%
path_awx = './test_data/FY2E_CTA_MLT_OTG_20170126_0130.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	DCZJ2613.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	80
# pad_length:	1081
# record_length:	1201
# head_records:	2
# data_records:	1201
# category:	3
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2Grd *
# satellite:	FY2E
# product:	20
# word_bytes:	1
# add_offset:	0
# scale_factor:	100
# time_flag:	0
# year:	2017
# month:	1
# day:	26
# hour:	1
# minute:	30
# year_end:	2017
# month_end:	1
# day_end:	26
# hour_end:	1
# minute_end:	55
# lat_n:	60.0
# lon_w:	27.0
# lat_s:	-60.0
# lon_e:	147.0
# reso_unit:	0
# reso_h:	10
# reso_v:	10
# width:	1201
# height:	1201
# land_flag:	0
# land_value:	0
# cloud_flag:	0
# cloud_value:	0
# water_flag:	0
# water_value:	0
# ice_flag:	0
# ice_value:	0
# qc_flag:	1
# qc_upper:	100
# qc_lower:	0
# reserved:	0
# projection:	4
#
# * Head3 *
# sat2004:	FY2E_CTA_MLT_OTG_20170126_0130.AWX
# format_version:	AWX2.0
# manufacturer:	NSMC
# satellite:	FY2E
# instrument:	VISSR
# program_version:	V1.0
# reserved:
# copy_right:	NSMC
# pad_length:	1073
# <xarray.Dataset>
# Dimensions:  (lat: 1201, lon: 1201)
# Coordinates:
#   * lat      (lat) float64 60.0 59.9 59.8 59.7 59.6 ... -59.7 -59.8 -59.9 -60.0
#   * lon      (lon) float64 27.0 27.1 27.2 27.3 27.4 ... 146.7 146.8 146.9 147.0
#     time     datetime64[ns] 2017-01-26T01:30:00
#     crs      float64 nan
# Data variables:
#     CTA      (lat, lon) uint8 98 98 98 98 98 98 98 98 ... 43 43 43 43 43 43 43

# %%
path_awx = './test_data/FY2G_TBB_IR1_OTG_20150729_0000.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	DMGL2900.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	80
# pad_length:	1081
# record_length:	1201
# head_records:	2
# data_records:	1201
# category:	3
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2Grd *
# satellite:	FY2G
# product:	19
# word_bytes:	1
# add_offset:	100
# scale_factor:	1
# time_flag:	0
# year:	2015
# month:	7
# day:	29
# hour:	0
# minute:	0
# year_end:	2015
# month_end:	7
# day_end:	29
# hour_end:	0
# minute_end:	25
# lat_n:	60.0
# lon_w:	45.0
# lat_s:	-60.0
# lon_e:	165.0
# reso_unit:	0
# reso_h:	10
# reso_v:	10
# width:	1201
# height:	1201
# land_flag:	0
# land_value:	0
# cloud_flag:	0
# cloud_value:	0
# water_flag:	0
# water_value:	0
# ice_flag:	0
# ice_value:	0
# qc_flag:	3
# qc_upper:	240
# qc_lower:	60
# reserved:	0
# projection:	4
#
# * Head3 *
# sat2004:	FY2G_TBB_IR1_OTG_20150729_0000.AWX
# format_version:	AWX2.0
# manufacturer:	NSMC
# satellite:	FY2G
# instrument:	VISSR
# program_version:	V1.0
# reserved:
# copy_right:	NSMC
# pad_length:	1073
# <xarray.Dataset>
# Dimensions:  (lat: 1201, lon: 1201)
# Coordinates:
#   * lat      (lat) float64 60.0 59.9 59.8 59.7 59.6 ... -59.7 -59.8 -59.9 -60.0
#   * lon      (lon) float64 45.0 45.1 45.2 45.3 45.4 ... 164.7 164.8 164.9 165.0
#     time     datetime64[ns] 2015-07-29
#     crs      float64 nan
# Data variables:
#     TBB      (lat, lon) uint8 149 146 144 145 143 142 ... 113 114 115 115 116

# %%
path_awx = './test_data/Z_SATE_C_BAWX_20230219054449_P_FY2G_CLC_MLT_OTG_20230219_0500.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	DCCF1950.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	80
# pad_length:	881
# record_length:	1001
# head_records:	2
# data_records:	1001
# category:	3
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2Grd *
# satellite:	FY2G
# product:	21
# word_bytes:	1
# add_offset:	0
# scale_factor:	1
# time_flag:	0
# year:	2023
# month:	2
# day:	19
# hour:	5
# minute:	0
# year_end:	2023
# month_end:	2
# day_end:	19
# hour_end:	5
# minute_end:	25
# lat_n:	55.0
# lon_w:	55.0
# lat_s:	-45.0
# lon_e:	155.0
# reso_unit:	0
# reso_h:	10
# reso_v:	10
# width:	1001
# height:	1001
# land_flag:	0
# land_value:	0
# cloud_flag:	0
# cloud_value:	0
# water_flag:	0
# water_value:	0
# ice_flag:	0
# ice_value:	0
# qc_flag:	1
# qc_upper:	100
# qc_lower:	0
# reserved:	0
# projection:	4
#
# * Head3 *
# sat2004:	FY2G_CLC_MLT_OTG_20230219_0500.AWX
# format_version:	AWX2.0
# manufacturer:	NSMC
# satellite:	FY2G
# instrument:	VISSR
# program_version:	V1.0
# reserved:
# copy_right:	NSMC
# pad_length:	873
# <xarray.Dataset>
# Dimensions:  (lat: 1001, lon: 1001)
# Coordinates:
#   * lat      (lat) float64 55.0 54.9 54.8 54.7 54.6 ... -44.7 -44.8 -44.9 -45.0
#   * lon      (lon) float64 55.0 55.1 55.2 55.3 55.4 ... 154.7 154.8 154.9 155.0
#     time     datetime64[ns] 2023-02-19T05:00:00
#     crs      float64 nan
# Data variables:
#     CLC      (lat, lon) uint8 21 21 21 21 21 21 21 21 ... 21 21 21 21 21 21 21 0

# %%
from BiteAWX import AWX
path_awx = './test_data/Z_SATE_C_BAWX_20230330005121_P_FY2G_AMV_IR1_OTG_20230329_2330.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.Dataset()
# Out:
# * Head1 *
# sat96:	TWDM29N0.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	40
# pad_length:	0
# record_length:	40
# head_records:	6
# data_records:	27107
# category:	4
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2Pts *
# satellite:	fy2g
# product:	101
# words:	40
# points:	27101
# year:	2023
# month:	3
# day:	29
# hour:	23
# minute:	30
# year_end:	2023
# month_end:	3
# day_end:	29
# hour_end:	23
# minute_end:	55
# inversion:	0
# first_guess:	0
# missing_value:	0
# word_bytes:	2
#
# * No Head3 found *
# <xarray.Dataset>
# Dimensions:  (index: 27096)
# Coordinates:
#     lat      (index) float64 61.57 61.59 61.65 60.52 ... 594.1 594.0 594.0 0.0
#     lon      (index) float64 106.9 107.8 111.1 106.9 ... 111.7 112.5 113.3 0.0
#     p        (index) uint16 369 357 316 379 362 381 ... 445 442 440 436 466 0
#     time     datetime64[ns] 2023-03-29T23:30:00
# Dimensions without coordinates: index
# Data variables:
#     dir      (index) uint16 268 267 264 257 268 290 ... 247 247 240 240 241 0
#     spd      (index) uint16 25 28 28 34 25 23 22 19 ... 25 22 22 22 20 16 16 0
#     tmp      (index) float64 231.4 229.8 223.6 233.2 ... 232.3 231.8 235.2 0.0
# Attributes: (12/17)
#     Head2Pts.satellite:      fy2g
#     Head2Pts.product:        101
#     Head2Pts.words:          40
#     Head2Pts.points:         27101
#     Head2Pts.year:           2023
#     Head2Pts.month:          3
#     ...                      ...
#     Head2Pts.day_end:        29
#     Head2Pts.hour_end:       23
#     Head2Pts.minute_end:     55
#     Head2Pts.inversion:      0
#     Head2Pts.first_guess:    0
#     Head2Pts.missing_value:  0
