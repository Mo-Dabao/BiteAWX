# %% [markdown]
# # Demo

# %%
from BiteAWX import AWX

# %%
path_awx = './test_data/ANI_IR2_R01_20230217_0800_FY2G.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.DataArray()
# Out:
# * Head1 *
# sat96:	ESLF170A.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	248
# record_length:	1200
# head_records:	3
# data_records:	1200
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY2G
# year:	2023
# month:	2
# day:	17
# hour:	0
# minute:	0
# channel:	3
# projection:	1
# width:	1200
# height:	1200
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	62.06
# lat_s:	6.59
# lon_w:	77.32
# lon_e:	148.7
# lat_c:	35.0
# lon_c:	100.0
# prj_std1:	30.0
# prj_std2:	60.0
# reso_h:	5.0
# reso_v:	5.0
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * Head3 *
# sat2004:	/DPCFY2G/L1/ANI/FY2G_ANI_IR2_R01_20230217_0000.AWX
# format_version:	SAT2004
# manufacturer:	NSMC
# satellite:	FY2G
# instrument:
# program_version:	V1.0
# reserved:
# copy_right:	NSMC
# pad_length:
# <xarray.DataArray 'ANI' (y: 1200, x: 1200)>
# ...

# %%
path_awx = './test_data/ANI_VIS_R02_20230217_1000_FY2G.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.DataArray()
# Out:
# * Head1 *
# sat96:	EVNF172A.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	76
# record_length:	2228
# head_records:	2
# data_records:	1100
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY2G
# year:	2023
# month:	2
# day:	17
# hour:	2
# minute:	0
# channel:	4
# projection:	2
# width:	2228
# height:	1100
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	41.05
# lat_s:	-4.25
# lon_w:	59.98
# lon_e:	160.0
# lat_c:	20.0
# lon_c:	110.0
# prj_std1:	30.0
# prj_std2:	60.0
# reso_h:	5.0
# reso_v:	5.0
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * Head3 *
# sat2004:	/DPCFY2G/L1/ANI/FY2G_ANI_VIS_R02_20230217_0200.AWX
# format_version:	SAT2004
# manufacturer:	NSMC
# satellite:	FY2G
# instrument:
# program_version:	V1.0
# reserved:
# copy_right:	NSMC
# pad_length:
# <xarray.DataArray 'ANI' (y: 1100, x: 2228)>
# ...

# %%
path_awx = './test_data/C002_20190302081500_FY4A.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.DataArray()
# Out:
# * Head1 *
# sat96:	EIEN015C.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	4849
# record_length:	7001
# head_records:	1
# data_records:	4001
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY4-006
# year:	2019
# month:	3
# day:	2
# hour:	0
# minute:	15
# channel:	4
# projection:	4
# width:	7001
# height:	4001
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	55.0
# lat_s:	15.0
# lon_w:	70.0
# lon_e:	140.0
# lat_c:	35.0
# lon_c:	105.0
# prj_std1:	0.0
# prj_std2:	0.0
# reso_h:	0.05
# reso_v:	0.05
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * No Head3 found *
# <xarray.DataArray 'Unknown' (lat: 4001, lon: 7001)>
# array([[  3,   3,   3, ..., 111, 111, 111],
#        [  3,   3,   3, ..., 111, 111, 111],
#        [  3,   3,   3, ..., 111, 111, 111],
#        ...,
#        [  3,   3,   3, ...,  31,  31,  31],
# ...

# %%
path_awx = './test_data/C009_20190301161500_FY4A.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.DataArray()
# Out:
# * Head1 *
# sat96:	EIEN015C.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	1350
# record_length:	1751
# head_records:	2
# data_records:	1001
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY4-062
# year:	2019
# month:	3
# day:	1
# hour:	8
# minute:	15
# channel:	2
# projection:	4
# width:	1751
# height:	1001
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	55.0
# lat_s:	15.0
# lon_w:	70.0
# lon_e:	140.0
# lat_c:	35.0
# lon_c:	105.0
# prj_std1:	0.0
# prj_std2:	0.0
# reso_h:	0.05
# reso_v:	0.05
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * No Head3 found *
# <xarray.DataArray 'Unknown' (lat: 1001, lon: 1751)>
# array([[226, 226, 226, ..., 228, 228, 228],
#        [226, 227, 227, ..., 228, 228, 228],
#        [226, 226, 227, ..., 228, 229, 229],
#        ...,
#        [194, 194, 194, ..., 192, 192, 192],
# ...

# %%
path_awx = './test_data/C012_20190301160000_FY4A.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.DataArray()
# Out:
# * Head1 *
# sat96:	EIEN015C.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	349
# record_length:	2501
# head_records:	1
# data_records:	3501
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY4-108
# year:	2019
# month:	3
# day:	1
# hour:	8
# minute:	0
# channel:	1
# projection:	4
# width:	2501
# height:	3501
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	70.0
# lat_s:	-70.0
# lon_w:	70.0
# lon_e:	170.0
# lat_c:	0.0
# lon_c:	120.0
# prj_std1:	0.0
# prj_std2:	0.0
# reso_h:	0.05
# reso_v:	0.05
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * No Head3 found *
# <xarray.DataArray 'Unknown' (lat: 3501, lon: 2501)>
# array([[194, 194, 194, ..., 215, 215, 215],
#        [193, 193, 194, ..., 255, 255, 255],
#        [195, 195, 195, ..., 255, 255, 255],
#        ...,
#        [210, 210, 210, ..., 255, 255, 255],
# ...

# %%
path_awx = './test_data/C012_20190302101500_FY4A.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.DataArray()
# Out:
# * Head1 *
# sat96:	EIEN015C.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	2112
# pad_length:	1350
# record_length:	1751
# head_records:	2
# data_records:	1001
# category:	1
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2GSS *
# satellite:	FY4-108
# year:	2019
# month:	3
# day:	2
# hour:	2
# minute:	15
# channel:	1
# projection:	4
# width:	1751
# height:	1001
# line_tl:	0
# pixel_tl:	0
# sampling_rate:	1
# lat_n:	55.0
# lat_s:	15.0
# lon_w:	70.0
# lon_e:	140.0
# lat_c:	35.0
# lon_c:	105.0
# prj_std1:	0.0
# prj_std2:	0.0
# reso_h:	0.05
# reso_v:	0.05
# gridline_flag:	0
# gridline_value:	255
# palette_length:	0
# calibration_length:	2048
# positioning_length:	0
# reserved:	0
# word_bytes:	1
#
# * No Head3 found *
# <xarray.DataArray 'Unknown' (lat: 1001, lon: 1751)>
# array([[184, 184, 184, ..., 172, 172, 172],
#        [183, 181, 181, ..., 172, 172, 172],
#        [183, 183, 181, ..., 172, 173, 173],
#        ...,
#        [100, 100, 100, ..., 103, 103, 103],
# ...

# %%
path_awx = './test_data/FY2E_CTA_MLT_OTG_20170126_0130.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.DataArray()
# Out:
# * Head1 *
# sat96:	DCZJ2613.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	80
# pad_length:	1081
# record_length:	1201
# head_records:	2
# data_records:	1201
# category:	3
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2Grd *
# satellite:	FY2E
# product:	20
# word_bytes:	1
# add_offset:	0
# scale_factor:	100
# time_flag:	0
# year:	2017
# month:	1
# day:	26
# hour:	1
# minute:	30
# year_end:	2017
# month_end:	1
# day_end:	26
# hour_end:	1
# minute_end:	55
# lat_n:	60.0
# lon_w:	27.0
# lat_s:	-60.0
# lon_e:	147.0
# reso_unit:	0
# reso_h:	10
# reso_v:	10
# width:	1201
# height:	1201
# land_flag:	0
# land_value:	0
# cloud_flag:	0
# cloud_value:	0
# water_flag:	0
# water_value:	0
# ice_flag:	0
# ice_value:	0
# qc_flag:	1
# qc_upper:	100
# qc_lower:	0
# reserved:	0
# projection:	4
#
# * Head3 *
# sat2004:	FY2E_CTA_MLT_OTG_20170126_0130.AWX
# format_version:	AWX2.0
# manufacturer:	NSMC
# satellite:	FY2E
# instrument:	VISSR
# program_version:	V1.0
# reserved:
# ...

# %%
path_awx = './test_data/FY2G_TBB_IR1_OTG_20150729_0000.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.DataArray()
# Out:
# * Head1 *
# sat96:	DMGL2900.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	80
# pad_length:	1081
# record_length:	1201
# head_records:	2
# data_records:	1201
# category:	3
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2Grd *
# satellite:	FY2G
# product:	19
# word_bytes:	1
# add_offset:	100
# scale_factor:	1
# time_flag:	0
# year:	2015
# month:	7
# day:	29
# hour:	0
# minute:	0
# year_end:	2015
# month_end:	7
# day_end:	29
# hour_end:	0
# minute_end:	25
# lat_n:	60.0
# lon_w:	45.0
# lat_s:	-60.0
# lon_e:	165.0
# reso_unit:	0
# reso_h:	10
# reso_v:	10
# width:	1201
# height:	1201
# land_flag:	0
# land_value:	0
# cloud_flag:	0
# cloud_value:	0
# water_flag:	0
# water_value:	0
# ice_flag:	0
# ice_value:	0
# qc_flag:	3
# qc_upper:	240
# qc_lower:	60
# reserved:	0
# projection:	4
#
# * Head3 *
# sat2004:	FY2G_TBB_IR1_OTG_20150729_0000.AWX
# format_version:	AWX2.0
# manufacturer:	NSMC
# satellite:	FY2G
# instrument:	VISSR
# program_version:	V1.0
# reserved:
# ...

# %%
path_awx = './test_data/Z_SATE_C_BAWX_20230219054449_P_FY2G_CLC_MLT_OTG_20230219_0500.AWX'
awx = AWX(path_awx)
awx.to_netcdf()
print(awx.head1, '\n')
print(awx.head2, '\n')
print(awx.head3)
awx.DataArray()
# Out:
# * Head1 *
# sat96:	DCCF1950.AWX
# byte_order:	0
# head1_length:	40
# head2_length:	80
# pad_length:	881
# record_length:	1001
# head_records:	2
# data_records:	1001
# category:	3
# compress:	0
# version:	SAT2004
# quality:	0
#
# * Head2Grd *
# satellite:	FY2G
# product:	21
# word_bytes:	1
# add_offset:	0
# scale_factor:	1
# time_flag:	0
# year:	2023
# month:	2
# day:	19
# hour:	5
# minute:	0
# year_end:	2023
# month_end:	2
# day_end:	19
# hour_end:	5
# minute_end:	25
# lat_n:	55.0
# lon_w:	55.0
# lat_s:	-45.0
# lon_e:	155.0
# reso_unit:	0
# reso_h:	10
# reso_v:	10
# width:	1001
# height:	1001
# land_flag:	0
# land_value:	0
# cloud_flag:	0
# cloud_value:	0
# water_flag:	0
# water_value:	0
# ice_flag:	0
# ice_value:	0
# qc_flag:	1
# qc_upper:	100
# qc_lower:	0
# reserved:	0
# projection:	4
#
# * Head3 *
# sat2004:	FY2G_CLC_MLT_OTG_20230219_0500.AWX
# format_version:	AWX2.0
# manufacturer:	NSMC
# satellite:	FY2G
# instrument:	VISSR
# program_version:	V1.0
# reserved:
# copy_right:	NSMC
# ...
